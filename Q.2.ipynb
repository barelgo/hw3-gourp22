# %%
import numpy as np
import pandas as pd
import csv
import nltk
import string
import re
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
sno = nltk.stem.SnowballStemmer('english')

# %%
import json

with open('regular_index.json', encoding='utf-8') as fp:
    indx = json.loads(fp.read())

with open('inverted_index.json', encoding='utf-8') as fp:
    inv_indx = json.loads(fp.read())

with open('words_transformation.json', encoding='utf-8') as fp:
    final_dict = json.loads(fp.read())

with open('words_inverse_transformation.json', encoding='utf-8') as fp:
    final_dict_inv = json.loads(fp.read())

# %%
import os

path, dirs, files = next(os.walk("directory"))
file_count = len(files)

# %% [markdown]
# # Creating a dictionary of the inverse index with tf_idf score in order to compute the cosine similarity

# %%
from math import log
inv_indx_cosine = {i:[] for i in list(final_dict.keys())}
for word in list(final_dict.keys()):
    for i,l in enumerate(list(indx.values())):
        if int(word) in l:
            tf = l.count(int(word))/len(l)
            id_f = log(file_count/len(inv_indx[word]))
            inv_indx_cosine[word].append((i+1,tf*id_f))

# %% [markdown]
# # Creating the respective index dictionary

# %%
indx_cosine = {}
for doc in range(file_count):
    indx_cosine[str(doc+1)] = []
    for term in list(final_dict.keys()):
        if int(doc+1) in [r for r in inv_indx[str(term)]]:
            k  = inv_indx[term].index(doc+1)
            indx_cosine[str(doc+1)].append((term,inv_indx_cosine[term][k][1]))

# %%
with open('inverted_index_cosine.json', 'w') as fp:
    json.dump(inv_indx_cosine, fp)
    
with open('index_cosine.json', 'w') as fp:
    json.dump(indx_cosine, fp)

# %%
query = 'a beautiful house with garden and beach'

# %%
m_raw = query
#replace $ with dollar
m = re.sub('[$]','dollar',m_raw)
# replace new line symbols with whitespace
m = m.replace('\\r', ' ').replace('\\n', ' ')
#remove punctuations with 2 ways
#m = ''.join([c for c in m if c not in string.punctuation])
m = re.sub('[%s]' % re.escape(string.punctuation), ' ', m)
# seperate numbers from words
m = re.sub(r'(?<=[\d+])(?=[a-zA-Z_])', r' ', m)
# remove digits from messages
#m = ''.join(c for c in m if not c.isdigit())
m_new = nltk.tokenize.word_tokenize(m)
#remove stopwords
m_new = [word for word in m_new if word.lower() not in stopwords.words('english')]
#stemming of words
q = [sno.stem(word) for word in m_new]

# %%
from collections import Counter
q_new = Counter([final_dict_inv[str(element)] for element in q if element in list(final_dict.values())])
documents = [inv_indx_cosine[str(term)] for term in list(q_new.keys())]
documents_final = set([y[0] for x in documents for y in x]) # in order to find the cosine similarity different to zero and save time

# %% [markdown]
# ## Computing of the cosine similarity between the query and each document and saving into a heap data structure

# %%
from heapq import heappush, heappop
from math import sqrt
similarity = []
for doc in documents_final:
    s = 0
    for term in list(q_new.keys()):
# in order to compute the inner product between the documents and the query in which the terms of the query exists
        if doc in inv_indx[str(term)]:  
            k  = inv_indx[str(term)].index(doc)
            s += inv_indx_cosine[str(term)][k][1]*(q_new[term]/len(q_new))
            #s += inv_indx_cosine[term][k][1]*(q_new[term])
    qm = sqrt(sum([k/len(q_new)**2 for k in q_new.values()]))
    #qm = sqrt(sum([k**2 for k in q_new.values()]))  ## compute without dividing with the length of the query
    dm = sqrt(sum([k[1]**2 for k in indx_cosine[str(doc)]]))
    #similarity.append((doc,s/(sqrt(qm)*sqrt(dm))))  ## ------------//-----------//-----------//--------
    heappush(similarity,(s/(sqrt(qm)*sqrt(dm)),doc))

# %%
#keeping only top-k documents
k = 100
for i in range(len(similarity)-k):
    heappop(similarity)

# %%
# sorting of the documents according the similarity with the query
similarity = sorted(similarity)[::-1]
cols=['Title','Description','City','Url']
df = pd.DataFrame([])
docs = [k[1] for k in similarity]
for i in range(len(docs)):
    filename = 'directory/doc_{}.tsv'.format(docs[i])
    #[7,4,2,8] taking only the elements that I was=nt to show to the user --> ['Title','Description','City','Url']
    df = df.append(pd.read_csv(filename,sep='\t',header=None).T.loc[:,[7,4,2,8]],ignore_index=True)
#df['Similarity']. = similarity[i][0]
df.columns = cols
df['Similarity'] = [k[0] for k in similarity]
df.index = list(range(1,101))

# %%
df
# Out:
#                                                  Title  \
# 1                            peacful garden guest room
# 2                      Charming 4 bedrooms beach house
# 3                         "Cottage by the Beach" condo
# 4                           Beautiful, New Beach House
# 5      Beach View Home - Ideal Location. Crystal Beach
# 6      Beach View Home - Ideal Location. Crystal Beach
# 7                        Queen Overlooking the Gardens
# 8                        Queen Overlooking the Gardens
# 9                        Queen Overlooking the Gardens
# 10                       Queen Overlooking the Gardens
# 11                                        Garden Suite
# 12                                       Beach Retreat
# 13                              Serendipity by the Sea
# 14   Beautiful North Beach Condo with Ocean/Beach v...
# 15   Beautiful North Beach Condo with Ocean/Beach v...
# 16                  Queen Room Overlooking the Gardens
# 17     New and beautiful beach house-Crystal Beach, TX
# 18                          Tropical Beach Front House
# 19                                        Vista Breeze
# 20                                      Beach Walk 016
# 21       ***Best Beach Views of Fireworks in Corpus***
# 22       ***Best Beach Views of Fireworks in Corpus***
# 23                                Beautiful Beach Home
# 24    Elegant beach view condo on Corpus Christi Beach
# 25                     Beautiful custom home ON beach!
# 26                     Corpus Christi Beach Condo 3313
# 27   Happy Destiny is beach front in Surfside Beach...
# 28                          Charming Beach Front House
# 29                     Corpus Christi Beach Condo 3213
# 30                 Alla's Garden House in S.W. Dallas.
# ..                                                 ...
# 71       New Spacious Beach House on Bolivar Peninsula
# 72                                Padre Beach View 209
# 73              Private Beach, Direct Water Views, 4BR
# 74                            Sandy Toes Beach Retreat
# 75                    Bahama Wannabe w/Beautiful Views
# 76                   First Floor & Short Walk to Beach
# 77                 Bright & Clean Beach House w/ View!
# 78                 Bright & Clean Beach House w/ View!
# 79                                      The Lake House
# 80                     New House with Pond View & Pool
# 81                    Victorian Condominium Beach View
# 82                Front Row Beautiful Newer Beach Home
# 83                 Cozy, large, 5 minute walk to beach
# 84                                      Beach Bungalow
# 85                               Surfside paradise # 1
# 86   Great view of dowtown Corpus Christi and the B...
# 87                          Beach Front Beauty - House
# 88                          Beach Front Beauty - House
# 89                      Garden Acres BCS Home near A&M
# 90                      Garden Acres BCS Home near A&M
# 91                      Garden Acres BCS Home near A&M
# 92                                     Down by the Sea
# 93               Brand New at Padre Beach View Resort!
# 94                 Sea N Stars: Gulf Front Beach House
# 95                     BEACHFRONT! SECLUDED BEACH HOME
# 96                          My house is big and quite.
# 97                       Short Walk to Beach with View
# 98        LEEWARD COVE A6 2 BED, 1.5 BTH, WALK 2 BEACH
# 99        LEEWARD COVE A6 2 BED, 1.5 BTH, WALK 2 BEACH
# 100  Perfect Beach House Sleeps 10+ Pool- P#(PHONE ...
#
#                                            Description                City  \
# 1              beautiful garden room with larg closet.         San Antonio
# 2    Beautiful beach house at surfside beach , grea...      Surfside Beach
# 3                                                    \           Galveston
# 4    Our house is close to restaurants and dining, ...       Crystal Beach
# 5                                                    \       Crystal Beach
# 6                                                    \       Crystal Beach
# 7    Queen room upstairs overlooking the gardens wi...           Glen Rose
# 8    Queen room upstairs overlooking the gardens wi...           Glen Rose
# 9    Queen room downstairs overlooking the gardens ...           Glen Rose
# 10   Queen room downstairs overlooking the gardens ...           Glen Rose
# 11   Deluxe garden suite with enclosed sun room wit...           Glen Rose
# 12   Welcome to Beach Retreat!\n\nThis property is ...      Corpus Christi
# 13   Beautiful home located in the heart of Crystal...       Crystal Beach
# 14   My place is good for couples, solo adventurers...      Corpus Christi
# 15   My place is good for couples, solo adventurers...      Corpus Christi
# 16   Queen room upstairs overlooking the gardens wi...           Glen Rose
# 17   Beautiful new beach house in Crystal Beach, TX...           Galveston
# 18   This is a 3 bedroom/2 bath beach house in Crys...       CRYSTAL BEACH
# 19   New house just one block from the beach. This ...           Galveston
# 20   Beach Walk Loop 16 is a great option for guest...      Corpus Christi
# 21       The Condo is right on the beach, located on \      Corpus Christi
# 22       The Condo is right on the beach, located on \      Corpus Christi
# 23   Come and relax in this beautiful beach home. Y...      Surfside Beach
# 24   Wonderfully remodeled beach view condo! Direct...      Corpus Christi
# 25   Welcome to our home, Sea Dreams Beach House! W...            Freeport
# 26   Quiet clean and on the beach. Come relax in th...      Corpus Christi
# 27   Property is beach front with a wonderful view ...            Freeport
# 28   Charming &amp; colorful beach house. 3 bedroom...            Freeport
# 29                Quiet, clean and close to the beach!      Corpus Christi
# 30   Welcome to Alla's Garden House! \nBeautiful pr...         Duncanville
# ..                                                 ...                 ...
# 71   Our place is located in a nice quiet neighborh...       CRYSTAL BEACH
# 72   Padre Beach View 209 is an All-New 4 bedroom/3...      Corpus Christi
# 73   Classic 4BR/2BA Rockport beach house with its ...            Rockport
# 74   It's finally here and we are happy to share ou...           Galveston
# 75   Bahama Wannabe is our beautiful beach home on ...       Crystal Beach
# 76   Our first floor condo at Gulfview II \nThe Gul...  South Padre Island
# 77   Toes in the Sand is a brand new home located i...   Bolivar Peninsula
# 78   Toes in the Sand is a brand new home located i...   Bolivar Peninsula
# 79              House, 3 Bedrooms, 2 Baths, (Sleeps 6)         Canyon Lake
# 80   Sea Foam - Is the Perfect Family Beach House -...        Port Aransas
# 81   Victorian Condominiums Beach Front View Top Floor           Galveston
# 82   Beautiful 2013 front row beach house setup to ...      Surfside Beach
# 83   Have your family or friends over for a fun wee...           Galveston
# 84   Beach Bungalow is a 2 bedroom townhouse locate...      Corpus Christi
# 85   Comfortably sleeps 10 people. Open floor plan,...      Surfside Beach
# 86   Beautiful cafe style condo right on the beach ...      Corpus Christi
# 87   This home is a beach front property. This is o...      Corpus Christi
# 88   This home is a beach front property. This is o...      Corpus Christi
# 89   This is a cute 1,700 sq. ft. home located in t...               Bryan
# 90   This is a cute 1,700 sq. ft. home located in t...               Bryan
# 91   This is a cute 1,700 sq. ft. home located in t...               Bryan
# 92   Down by the Sea is luxury at the beach! It is ...           Galveston
# 93   Welcome to the brand-new Endless Summer II at ...      Corpus Christi
# 94   Come relax at Sea n Stars, our Gulf shore beac...             Sargent
# 95   Bluewater Retreat is a gorgeous Cape Cod style...            Freeport
# 96   My house is a Mexican rustic decorate. Big roo...         San Antonio
# 97   Our 6th Floor condo at The Gulfview II gives y...  South Padre Island
# 98   Beautiful 2 bedroom 1.5 bath condo a block fro...      Corpus Christi
# 99   Beautiful 2 bedroom 1.5 bath condo a block fro...      Corpus Christi
# 100  Newly renovated open floorplan completely equi...  South Padre Island
#
#                                                    Url  Similarity
# 1    https://www.airbnb.com/rooms/18235720?location...    0.333165
# 2    https://www.airbnb.com/rooms/16841588?location...    0.268824
# 3    https://www.airbnb.com/rooms/9383668?location=...    0.236307
# 4    https://www.airbnb.com/rooms/15068378?location...    0.232600
# 5    https://www.airbnb.com/rooms/13837834?location...    0.227137
# 6    https://www.airbnb.com/rooms/13837834?location...    0.227137
# 7    https://www.airbnb.com/rooms/11982728?location...    0.212739
# 8    https://www.airbnb.com/rooms/11982664?location...    0.212739
# 9    https://www.airbnb.com/rooms/11968178?location...    0.210935
# 10   https://www.airbnb.com/rooms/11967653?location...    0.210935
# 11   https://www.airbnb.com/rooms/11964410?location...    0.210635
# 12   https://www.airbnb.com/rooms/13803843?location...    0.208507
# 13   https://www.airbnb.com/rooms/10681192?location...    0.207342
# 14   https://www.airbnb.com/rooms/15270320?location...    0.205350
# 15   https://www.airbnb.com/rooms/15270320?location...    0.205350
# 16   https://www.airbnb.com/rooms/11982395?location...    0.202129
# 17   https://www.airbnb.com/rooms/11696693?location...    0.201812
# 18   https://www.airbnb.com/rooms/656452?location=A...    0.194337
# 19   https://www.airbnb.com/rooms/18371258?location...    0.184848
# 20   https://www.airbnb.com/rooms/13804596?location...    0.184752
# 21   https://www.airbnb.com/rooms/3128031?location=...    0.178262
# 22   https://www.airbnb.com/rooms/3128031?location=...    0.178262
# 23   https://www.airbnb.com/rooms/5040170?location=...    0.174098
# 24   https://www.airbnb.com/rooms/19413021?location...    0.173588
# 25   https://www.airbnb.com/rooms/6179121?location=...    0.170851
# 26   https://www.airbnb.com/rooms/9956864?location=...    0.169977
# 27   https://www.airbnb.com/rooms/18895633?location...    0.169934
# 28   https://www.airbnb.com/rooms/4532740?location=...    0.167437
# 29   https://www.airbnb.com/rooms/9561139?location=...    0.163593
# 30   https://www.airbnb.com/rooms/286328?location=C...    0.163077
# ..                                                 ...         ...
# 71   https://www.airbnb.com/rooms/13168618?location...    0.141135
# 72   https://www.airbnb.com/rooms/13805990?location...    0.140977
# 73   https://www.airbnb.com/rooms/17037530?location...    0.140870
# 74   https://www.airbnb.com/rooms/16980825?location...    0.140847
# 75   https://www.airbnb.com/rooms/3510352?location=...    0.140638
# 76   https://www.airbnb.com/rooms/12326546?location...    0.140290
# 77   https://www.airbnb.com/rooms/507942?location=A...    0.139678
# 78   https://www.airbnb.com/rooms/507942?location=B...    0.139678
# 79   https://www.airbnb.com/rooms/17076807?location...    0.138909
# 80   https://www.airbnb.com/rooms/11451221?location...    0.138350
# 81   https://www.airbnb.com/rooms/16692907?location...    0.138125
# 82   https://www.airbnb.com/rooms/12790025?location...    0.137840
# 83   https://www.airbnb.com/rooms/16720966?location...    0.136672
# 84   https://www.airbnb.com/rooms/13802623?location...    0.136600
# 85   https://www.airbnb.com/rooms/15073135?location...    0.136500
# 86   https://www.airbnb.com/rooms/19433300?location...    0.135651
# 87   https://www.airbnb.com/rooms/13921867?location...    0.135034
# 88   https://www.airbnb.com/rooms/13921867?location...    0.135034
# 89   https://www.airbnb.com/rooms/12107509?location...    0.134899
# 90   https://www.airbnb.com/rooms/12107509?location...    0.134899
# 91   https://www.airbnb.com/rooms/12107509?location...    0.134899
# 92   https://www.airbnb.com/rooms/16359498?location...    0.134781
# 93   https://www.airbnb.com/rooms/17172107?location...    0.134417
# 94   https://www.airbnb.com/rooms/6589546?location=...    0.134379
# 95   https://www.airbnb.com/rooms/4066646?location=...    0.134085
# 96   https://www.airbnb.com/rooms/7378323?location=...    0.134065
# 97   https://www.airbnb.com/rooms/11886390?location...    0.134062
# 98   https://www.airbnb.com/rooms/19550824?location...    0.133787
# 99   https://www.airbnb.com/rooms/19550824?location...    0.133787
# 100  https://www.airbnb.com/rooms/11121926?location...    0.133426
#
# [100 rows x 5 columns]

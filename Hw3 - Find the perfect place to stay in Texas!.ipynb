# %% [markdown]
# # Find the perfect place to stay in Texas!

# %% [markdown]
# In this notebook is analyzed the text of Airbnb property listings and builded a search engine.

# %% [markdown]
# First of all we imported all the libraries needed for this purpose.

# %%
import numpy as np
import pandas as pd
import csv
import nltk
import string
import re
import os
import json
import matplotlib.pyplot as plt
import folium as fl

from geopy import distance
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from collections import Counter
from math import log
from heapq import heappush, heappop
from sklearn.cluster import KMeans
from math import sqrt
from scipy.stats import chisquare
from heapq import heappush, heappop

# %% [markdown]
# ### Data Cleaning Function

# %% [markdown]
# It's defined here a data cleaning function, used to clean all the reviews' texts and later on the queries.
# A number of steps are performed for the task:
# - replace $ with 'dollar', to avoid losing relevant information from the text
# - replace new line symbols with whitespace
# - remove puntuation
# - separate numbers from words
# - remove stopwords
# - tokenize the text
# - stem of the words, just keeping the root

# %%
def string_cleaning(string_raw):

    m = re.sub('[$]','dollar',string_raw)
    m = m.replace('\\r', ' ').replace('\\n', ' ')
    m = re.sub('[%s]' % re.escape(string.punctuation), ' ', m)
    m = re.sub(r'(?<=[\d+])(?=[a-zA-Z_])', r' ', m)
    m = nltk.tokenize.word_tokenize(m)
    m = [word for word in m if word.lower() not in stopwords.words('english')]
    sno = nltk.stem.SnowballStemmer('english')
    string_new = [sno.stem(word) for word in m]
    
    return string_new

# %% [markdown]
# ## Conjunctive query

# %%
path, dirs, files = next(os.walk("directory"))
file_count = len(files)

# %% [markdown]
# ### Creating a full corpus with all the words appeared in the descriptions and the titles

# %%
corpus = []
for i in range(file_count):
    filename = 'directory/doc_{}.tsv'.format(i+1)
    with open(filename,encoding='utf8') as tsvfile:
        reader = csv.reader(tsvfile, delimiter='\t')
        document = []
        for row in reader:
            document.append(row)
        corpus.append(document[4][0] + document[7][0])

# %% [markdown]
# For each word in the corpus it's performed the data cleaning and tokenization and the corpus has been flattened for the words' occurrence.

# %%
lista = []
for i in range(len(corpus)):
    lista.append(string_cleaning(corpus[i]))
    

lista_flatten = [y for x in lista for y in x]

# %% [markdown]
# The next step is to create a dictionary with all the words counted and then sorted by frequency.

# %%
c = Counter(lista_flatten)
c= dict(c.most_common())

final_dict = {str(i+1):x for i,x in enumerate(c)}
final_dict_inv = {str(x):(i+1) for i,x in enumerate(c)}

# %% [markdown]
# ### Index  and Inverse Index dictionary

# %%
indx = {}
for n,document in enumerate(lista):
    new_document = []
    for word in document:
        new_document.append(final_dict_inv[str(word)])
    indx[str(n+1)] = new_document 
    
inv_indx = {str(i):[] for i in list(final_dict.keys())}
for word in list(final_dict.keys()):
    for i in range(len(indx)):
        if int(word) in indx[str(i+1)]:
            inv_indx[word].append(i+1)

# %% [markdown]
# For future usage, all the dictionaries are saved and loaded

# %%
with open('regular_index.json', 'w') as fp:
    json.dump(indx, fp)

with open('inverted_index.json', 'w') as fp:
    json.dump(inv_indx, fp)
    
with open('words_transformation.json', 'w') as fp:
    json.dump(final_dict, fp)    
    
with open('words_inverse_transformation.json', 'w') as fp:
    json.dump(final_dict_inv, fp)

# %%
with open('regular_index.json', encoding='utf-8') as fp:
    indx = json.loads(fp.read())

with open('inverted_index.json', encoding='utf-8') as fp:
    inv_indx = json.loads(fp.read())

with open('words_transformation.json', encoding='utf-8') as fp:
    final_dict = json.loads(fp.read())

with open('words_inverse_transformation.json', encoding='utf-8') as fp:
    final_dict_inv = json.loads(fp.read())

# %% [markdown]
# ## Execution of the example query

# %%
query = 'a beautiful house with garden'

# %% [markdown]
# The query has to be clean and the terms are sorted from the less frequent to make the search faster.

# %%
q = string_cleaning(query)

q_new = sorted([final_dict_inv[str(element)] for element in q if element in list(final_dict.values())])[::-1]
documents = [inv_indx[str(term)] for term in q_new]
documents_final = set(documents[0])
for l2 in documents[1:]:
    documents_final = documents_final.intersection(set(l2))

# %% [markdown]
# Once the search it's done it's needed to give the output.
# The only elements reported are Title, Description, City and Url.

# %%
cols=['Title','Description','City','Url']
df = pd.DataFrame([])
for i in documents_final:
    filename = 'directory/doc_{}.tsv'.format(i)
    df = df.append(pd.read_csv(filename,sep='\t',header=None).T.loc[:,[7,4,2,8]],ignore_index=True)

if df.empty:
    print('No match found!')
else:
    df.columns = cols
    df.index = list(range(1,len(documents_final)+1))

# %%
df.head(10)
# Out:
#                                                 Title  \
# 1                                Dallas Downton Abbey
# 2   Historic Mansion Downtown Ft Worth; Bass Hall;...
# 3   Unique Location! Alamo Heights - Designer Insp...
# 4                      The Vintage room in Fort Worth
# 5                Beautiful queen bedroom in NW Austin
# 6   Unique Location! Alamo Heights - Designer Insp...
# 7                            East Austin Hillside Gem
# 8   The Woodlands, BEAUTIFUL HOME, 1 Floor, 2 BT, ...
# 9            Stylish Stone Cottage on White Rock Lake
# 10                Vintage Airstream in East Austin, T
#
#                                           Description         City  \
# 1   Our Dallas Downton Abbey is close to downtown,...       Dallas
# 2   Less than 2 miles from TCU, the Fort Worth Con...   Fort Worth
# 3   Stylish, fully remodeled home in upscale NW – ...  San Antonio
# 4   Our place is a beautiful cozy open concept hou...   Fort Worth
# 5   My house is close to Lakeline Mall, highways a...       Austin
# 6   Stylish, fully remodeled home in upscale NW – ...  San Antonio
# 7   Beautiful and modern 3Br, 2.5Ba located minute...       Austin
# 8   Attractions: The Woodlands, incredible views, ...       Spring
# 9   Newly remodeled, open-concept living located o...       Dallas
# 10  This fantastic backyard garden oasis has been ...       Austin
#
#                                                   Url
# 1   https://www.airbnb.com/rooms/14254297?location...
# 2   https://www.airbnb.com/rooms/8664808?location=...
# 3   https://www.airbnb.com/rooms/17481455?location...
# 4   https://www.airbnb.com/rooms/18959678?location...
# 5   https://www.airbnb.com/rooms/16755710?location...
# 6   https://www.airbnb.com/rooms/17481455?location...
# 7   https://www.airbnb.com/rooms/17555039?location...
# 8   https://www.airbnb.com/rooms/13065223?location...
# 9   https://www.airbnb.com/rooms/15132655?location...
# 10  https://www.airbnb.com/rooms/949922?location=B...

# %% [markdown]
# ## Conjunctive query & Ranking score (Cosine Similarity)

# %% [markdown]
# Once founded all the documents that contain the words in the query, we want to define a ranking with the cosine similarity to show the users the most relevant documents they could be interested in.

# %% [markdown]
# ### Cosine Index  and Inverse Cosine Index dictionary

# %% [markdown]
# To use the Cosine similarity it's needed to calcolate for each term:
# - the frequency in each document: TF
# - the IDF$_{i}$ defined has: $$IDF_{i}=\log{\frac{n}{N_{i}}}$$
# where i is refered to term i

# %%
inv_indx_cosine = {i:[] for i in list(final_dict.keys())}
for word in list(final_dict.keys()):
    for i,l in enumerate(list(indx.values())):
        if int(word) in l:
            tf = l.count(int(word))/len(l)
            id_f = log(file_count/len(inv_indx[word]))
            inv_indx_cosine[word].append((i+1,tf*id_f))
            
indx_cosine = {}
for doc in range(file_count):
    indx_cosine[str(doc+1)] = []
    for term in list(final_dict.keys()):
        if int(doc+1) in [r for r in inv_indx[str(term)]]:
            k  = inv_indx[term].index(doc+1)
            indx_cosine[str(doc+1)].append((term,inv_indx_cosine[term][k][1]))

# %% [markdown]
# For future usage the index are saved and loaded

# %%
with open('inverted_index_cosine.json', 'w') as fp:
    json.dump(inv_indx_cosine, fp)
    
with open('index_cosine.json', 'w') as fp:
    json.dump(indx_cosine, fp)

# %%
with open('inverted_index_cosine.json', encoding='utf-8') as fp:
    inv_indx_cosine = json.loads(fp.read())

with open('index_cosine.json', encoding='utf-8') as fp:
    indx_cosine = json.loads(fp.read())

# %% [markdown]
# ## Example Query Executing

# %% [markdown]
# Given a query, all the documents that contain all the terms are found, as previously

# %%
query = 'beautiful house in San Antonio'

q = string_cleaning(query)

q_new = Counter([final_dict_inv[str(element)] for element in q if element in list(final_dict.values())])

documents = [inv_indx[str(term)] for term in q_new]
documents_final = set(documents[0])
for l2 in documents[1:]:
    documents_final = documents_final.intersection(set(l2))

# %% [markdown]
# The results are store into a heap data structure.
# The similarity between the query and each documents has been calculate as:
# $$cos(q,d_{i})=\frac{\sum_{j=0}^n TF_{i}*IDF_{j}}{\left|q\right|*\left|d_{i}\right|}$$
# with j refered to the terms in the query and i to the document considered.

# %%
similarity = []
for doc in documents_final:
    s = 0
    for term in list(q_new.keys()):
        if doc in inv_indx[str(term)]:  
            k  = inv_indx[str(term)].index(doc)
            s += inv_indx_cosine[str(term)][k][1]*(q_new[term]/len(q_new))
    qm = sqrt(sum([k/len(q_new)**2 for k in q_new.values()]))
    dm = sqrt(sum([k[1]**2 for k in indx_cosine[str(doc)]]))
    heappush(similarity,(s/(sqrt(qm)*sqrt(dm)),doc))

k = 100
for i in range(len(similarity)-k):
    heappop(similarity)

# %% [markdown]
# ### Output
# All the documents are sorted according to the cosine similarity score.

# %%
similarity = sorted(similarity)[::-1]
cols=['Title','Description','City','Url']
df = pd.DataFrame([])
docs = [k[1] for k in similarity]
for i in range(len(docs)):
    filename = 'directory/doc_{}.tsv'.format(docs[i])
    df = df.append(pd.read_csv(filename,sep='\t',header=None).T.loc[:,[7,4,2,8]],ignore_index=True)
df.columns = cols
df['Similarity'] = [k[0] for k in similarity]
df.index = list(range(1,len(df)+1))
df
# Out:
#                                                 Title  \
# 1                 Cute two story house in San Antonio
# 2                 Cute two story house in San Antonio
# 3                  San Antonio Lake House on Lake LBJ
# 4                  San Antonio Lake House on Lake LBJ
# 5                 House Nestled in Quiet Neighborhood
# 6                 House Nestled in Quiet Neighborhood
# 7           A Cozy Home with a Beautiful Nature Views
# 8                                  Blanco River House
# 9   Priv. Room@Beautiful House by La Cantera/Six F...
# 10                        Private room in cozy house.
# 11  Beautiful 5BR House Dona Ana Cove, San Antonio...
# 12                                 Riverfront Retreat
# 13                       Historic Redbird Guest House
# 14  Spacious 2-story Family Home close to everything!
# 15                           Gorgeous Eclectic House.
# 16                           Gorgeous Eclectic House.
# 17  Entire home-Peaceful, relaxing, safe neighborhood
# 18       Sandra's Cottage w/Pool (Centrally Located!)
# 19                                     The Lake House
# 20                                     The Lake House
# 21                                     The Lake House
# 22               Charming Columbus, Tx Guest Quarters
# 23               Charming Columbus, Tx Guest Quarters
#
#                                           Description           City  \
# 1   Really nice quiet neighborhood in beautiful Sa...    San Antonio
# 2   Really nice quiet neighborhood in beautiful Sa...    San Antonio
# 3   The San Antonio Lake House is located in the T...      Kingsland
# 4   The San Antonio Lake House is located in the T...      Kingsland
# 5   I hope you’ll love my place because of the qui...    San Antonio
# 6   I hope you’ll love my place because of the qui...    San Antonio
# 7   This home is on the North Side of San Antonio,...    San Antonio
# 8   River House is just off the square in quaint B...         Blanco
# 9   - Stay in an Beautiful, relaxing house with gr...    San Antonio
# 10  Come and visit or stay longer here in beautifu...    San Antonio
# 11  Key in your travel dates to find out if qualif...        Helotes
# 12  Our retreat is close to Blanco State Park and ...         Blanco
# 13  Welcome to the historic Redbird Guest House! T...    San Antonio
# 14  This beautiful spacious home is perfect for yo...  New Braunfels
# 15  Our charming home with vintage and contemporar...    San Antonio
# 16  Our charming home with vintage and contemporar...    San Antonio
# 17  Relax and enjoy yourself in my Texas Hill Coun...    San Antonio
# 18  Beautifully decorated cottage. Quaint, cozy, a...    San Antonio
# 19  3 bedroom, 1 bath lakefront house with 80' wat...   Marble Falls
# 20  3 bedroom, 1 bath lakefront house with 80' wat...   Marble Falls
# 21  3 bedroom, 1 bath lakefront house with 80' wat...   Marble Falls
# 22  My place is great for work or corporate stays,...       Columbus
# 23  My place is great for work or corporate stays,...       Columbus
#
#                                                   Url  Similarity
# 1   https://www.airbnb.com/rooms/11166341?location...    0.214126
# 2   https://www.airbnb.com/rooms/11166341?location...    0.214126
# 3   https://www.airbnb.com/rooms/13634952?location...    0.201379
# 4   https://www.airbnb.com/rooms/13634952?location...    0.201379
# 5   https://www.airbnb.com/rooms/18568735?location...    0.185773
# 6   https://www.airbnb.com/rooms/18568735?location...    0.185773
# 7   https://www.airbnb.com/rooms/19190311?location...    0.160501
# 8   https://www.airbnb.com/rooms/7159265?location=...    0.158954
# 9   https://www.airbnb.com/rooms/8557583?location=...    0.136170
# 10  https://www.airbnb.com/rooms/16507221?location...    0.129963
# 11  https://www.airbnb.com/rooms/12954474?location...    0.119742
# 12  https://www.airbnb.com/rooms/13528589?location...    0.110033
# 13  https://www.airbnb.com/rooms/18472139?location...    0.097076
# 14  https://www.airbnb.com/rooms/19586812?location...    0.095878
# 15  https://www.airbnb.com/rooms/18396644?location...    0.086588
# 16  https://www.airbnb.com/rooms/18396644?location...    0.086588
# 17  https://www.airbnb.com/rooms/5041349?location=...    0.079579
# 18  https://www.airbnb.com/rooms/13299372?location...    0.078059
# 19  https://www.airbnb.com/rooms/15820806?location...    0.066011
# 20  https://www.airbnb.com/rooms/15820806?location...    0.066011
# 21  https://www.airbnb.com/rooms/15820806?location...    0.066011
# 22  https://www.airbnb.com/rooms/18269171?location...    0.052527
# 23  https://www.airbnb.com/rooms/18269171?location...    0.052527

# %% [markdown]
# ## Define a new score!
# To define a new score other parametres are considered: the location, given by latitude and longitude, the average price per night, the number of bedrooms. A new dataframe with all this information is created.
#
# It's also needed a dictionary with the cities of Texas and their coordinates.

# %%
cols=['Average_rate_per_night','Bedrooms_count','City','Date_of_listing','Description','Latitude','Longitude','Title','Url']
df = pd.DataFrame([])
for i in range(file_count):
    filename = 'directory/doc_{}.tsv'.format(i+1)
    df = df.append(pd.read_csv(filename,sep='\t',header=None).T,ignore_index=True)
df.columns = cols


all_cities = pd.read_csv('uscitiesv1.4.csv')
texas = all_cities[all_cities.state_name=='Texas']

cities_cord = {}
for city in df.City.unique():
    if city in texas.city.values:
        cities_cord[city] = [texas[texas.city == city].lat.iloc[0],texas[texas.city == city].lng.iloc[0]]
        
df.dropna(inplace=True)
lat = df.Latitude.apply(pd.to_numeric,errors='coerce').values
long = df.Longitude.apply(pd.to_numeric,errors='coerce').values
X = [[l1,l2] for l1,l2 in zip(lat,long)]

# %% [markdown]
# To consider the different locations we decided to cluster them in 10 main areas.
# <br>
# First it's created a KMEANS clustering.
# <br>
# Then it's shown in a plot how the differt areas are divided.

# %%
kmeans = KMeans(n_clusters=10).fit(X)


# %matplotlib inline
plt.scatter(lat,long,c=kmeans.labels_)

# %% [markdown]
# ## Example query execution

# %% [markdown]
# From the user is now required a query, as previously, and some more informations: average price per night, number of bedrooms needed, location.
# <br>
# Through the dictionary or geolocator library the coordinates are obtained.
#
#
# The first part of the search is done as before.

# %%
query = 'beautiful house in San Antonio'
qprice = 60 
qrooms = 2
qarea = 'San Antonio'

if qarea in cities_cord.keys(): 
    la,lo = cities_cord[qarea]
else:
    from geopy.geocoders import Nominatim
    geolocator = Nominatim()
    la,lo = geolocator.geocode(qarea + " US")[-1]
qarea = kmeans.predict([[la,lo]])[0]+1 
q_values = [qprice/150,qrooms/10,qarea/10,la/30,lo/100]  


q = string_cleaning(query)
q_new = sorted([final_dict_inv[str(element)] for element in q if element in list(final_dict.values())])[::-1]
documents = [inv_indx[str(term)] for term in q_new]
documents_final = set(documents[0])
for l2 in documents[1:]:
    documents_final = documents_final.intersection(set(l2))

# %% [markdown]
# ## Finding Results

# %% [markdown]
# The documents containg each term are loaded.
# <br>
# The columns are cleaned and numerized.
# <br>
# At last is created a matrix in order to apply chi-square statistics to each row of it.

# %%
df = pd.DataFrame([])
for i in documents_final:
    filename = 'directory/doc_{}.tsv'.format(i)
    df = df.append(pd.read_csv(filename,sep='\t',header=None).T,ignore_index=True)
df.columns = cols
df.index = list(range(1,len(documents_final)+1))

df.Bedrooms_count.replace('Studio',1,inplace=True)

#Columns cleaning and numerization
price = df.Average_rate_per_night.str.split('$').str[-1].apply(pd.to_numeric).values
rooms = df.Bedrooms_count.apply(pd.to_numeric,errors='coerce').values
lat = df.Latitude.apply(pd.to_numeric,errors='coerce').values
long = df.Longitude.apply(pd.to_numeric,errors='coerce').values
lat = np.nan_to_num(lat)
long = np.nan_to_num(long)
X = [[l1,l2] for l1,l2 in zip(lat,long)]
cities = [kmeans.predict(X)][0]+1 

#Final Matrix
matrix = np.array([price/150,rooms/10,cities/10,lat/30,long/100]).T
matrix
# Out:
# array([[ 0.86666667,  0.3       ,  0.2       ,  0.98588211, -0.98381229],
#        [ 1.33333333,  0.3       ,  0.9       ,  0.99034007, -0.96539676],
#        [ 0.67333333,  0.1       ,  0.2       ,  0.98902128, -0.98658216],
#        [ 0.56666667,  0.3       ,  0.2       ,  0.98174469, -0.98510782],
#        [ 0.73333333,  0.1       ,  0.2       ,  0.98896771, -0.98418352],
#        [ 1.54666667,  0.3       ,  0.2       ,  0.98919173, -0.9813502 ],
#        [ 2.79333333,  0.5       ,  0.2       ,  0.98616125, -0.98660127],
#        [ 0.3       ,  0.1       ,  0.2       ,  0.98707973, -0.98616689],
#        [ 2.5       ,  0.3       ,  0.2       ,  1.00312822, -0.98410653],
#        [ 1.33333333,  0.3       ,  0.9       ,  0.99034007, -0.96539676],
#        [ 1.83333333,  0.3       ,  0.6       ,  1.01881093, -0.98281663],
#        [ 0.43333333,  0.2       ,  0.2       ,  0.98217756, -0.98353234],
#        [ 2.89333333,  0.2       ,  0.6       ,  1.02179612, -0.98433686],
#        [ 0.24666667,  0.1       ,  0.2       ,  0.98342892, -0.98650763],
#        [ 1.83333333,  0.3       ,  0.6       ,  1.01881093, -0.98281663],
#        [ 0.56666667,  0.3       ,  0.2       ,  0.98174469, -0.98510782],
#        [ 0.93333333,  0.3       ,  0.2       ,  0.98782585, -0.98492491],
#        [ 0.83333333,  0.1       ,  0.2       ,  0.98155447, -0.98810307],
#        [ 0.43333333,  0.2       ,  0.2       ,  0.98217756, -0.98353234],
#        [ 1.83333333,  0.3       ,  0.6       ,  1.01881093, -0.98281663],
#        [ 1.        ,  0.4       ,  0.2       ,  1.00326231, -0.98413678],
#        [ 2.89333333,  0.2       ,  0.6       ,  1.02179612, -0.98433686],
#        [ 0.86666667,  0.3       ,  0.2       ,  0.98588211, -0.98381229]])

# %% [markdown]
# #### Apply chi-square statistics test and heappushing of the data

# %% [markdown]
# For each document is given a score with the chi-square method.
# <br>
# Again the top-k documents are stored in a heap data structure.

# %%
score = []
for i in range(matrix.shape[0]):
    heappush(score,(chisquare(q_values,f_exp=matrix[i])[-1],list(documents_final)[i]))  
    
k = 100
score = sorted(score)[::-1]
for i in range(len(score)-k):
    heappop(score)

# %% [markdown]
# The top-k documents are given as output for the user.

# %%
df = pd.DataFrame([])
score = sorted(score)[::-1]
docs = [k[1] for k in score]
for i in range(len(docs)):
    filename = 'directory/doc_{}.tsv'.format(docs[i])
    df = df.append(pd.read_csv(filename,sep='\t',header=None).T,ignore_index=True)
df.columns = cols
df['Ranking'] = [k[0] for k in score]
df['Latitude'] = df['Latitude'].astype('float64')
df['Longitude'] = df['Longitude'].astype('float64')
df.index = list(range(1,len(df)+1))
df
# Out:
#    Average_rate_per_night Bedrooms_count           City Date_of_listing  \
# 1                     $65              2    San Antonio       July 2015
# 2                     $65              2    San Antonio       July 2015
# 3                     $85              3    San Antonio      March 2017
# 4                     $85              3    San Antonio      March 2017
# 5                     $45              1    San Antonio      April 2015
# 6                     $37              1    San Antonio   December 2016
# 7                    $101              1    San Antonio       June 2016
# 8                    $110              1    San Antonio       June 2017
# 9                    $130              3    San Antonio    October 2011
# 10                   $130              3    San Antonio    October 2011
# 11                   $125         Studio    San Antonio      April 2017
# 12                   $140              3    San Antonio      March 2014
# 13                   $150              4         Blanco       July 2015
# 14                   $232              3  New Braunfels       June 2017
# 15                   $200              3       Columbus      April 2017
# 16                   $200              3       Columbus      April 2017
# 17                   $275              3   Marble Falls       July 2014
# 18                   $275              3   Marble Falls       July 2014
# 19                   $275              3   Marble Falls       July 2014
# 20                   $375              3         Blanco      April 2016
# 21                   $419              5        Helotes  September 2015
# 22                   $434              2      Kingsland      April 2016
# 23                   $434              2      Kingsland      April 2016
#
#                                           Description   Latitude  Longitude  \
# 1   I hope you’ll love my place because of the qui...  29.465327 -98.353234
# 2   I hope you’ll love my place because of the qui...  29.465327 -98.353234
# 3   Our charming home with vintage and contemporar...  29.452341 -98.510782
# 4   Our charming home with vintage and contemporar...  29.452341 -98.510782
# 5   - Stay in an Beautiful, relaxing house with gr...  29.612392 -98.616689
# 6   Come and visit or stay longer here in beautifu...  29.502868 -98.650763
# 7   Beautifully decorated cottage. Quaint, cozy, a...  29.670638 -98.658216
# 8   This home is on the North Side of San Antonio,...  29.669031 -98.418352
# 9   Really nice quiet neighborhood in beautiful Sa...  29.576463 -98.381229
# 10  Really nice quiet neighborhood in beautiful Sa...  29.576463 -98.381229
# 11  Welcome to the historic Redbird Guest House! T...  29.446634 -98.810307
# 12  Relax and enjoy yourself in my Texas Hill Coun...  29.634775 -98.492491
# 13  River House is just off the square in quaint B...  30.097869 -98.413678
# 14  This beautiful spacious home is perfect for yo...  29.675752 -98.135020
# 15  My place is great for work or corporate stays,...  29.710202 -96.539676
# 16  My place is great for work or corporate stays,...  29.710202 -96.539676
# 17  3 bedroom, 1 bath lakefront house with 80' wat...  30.564328 -98.281663
# 18  3 bedroom, 1 bath lakefront house with 80' wat...  30.564328 -98.281663
# 19  3 bedroom, 1 bath lakefront house with 80' wat...  30.564328 -98.281663
# 20  Our retreat is close to Blanco State Park and ...  30.093847 -98.410653
# 21  Key in your travel dates to find out if qualif...  29.584838 -98.660127
# 22  The San Antonio Lake House is located in the T...  30.653884 -98.433686
# 23  The San Antonio Lake House is located in the T...  30.653884 -98.433686
#
#                                                 Title  \
# 1                 House Nestled in Quiet Neighborhood
# 2                 House Nestled in Quiet Neighborhood
# 3                            Gorgeous Eclectic House.
# 4                            Gorgeous Eclectic House.
# 5   Priv. Room@Beautiful House by La Cantera/Six F...
# 6                         Private room in cozy house.
# 7        Sandra's Cottage w/Pool (Centrally Located!)
# 8           A Cozy Home with a Beautiful Nature Views
# 9                 Cute two story house in San Antonio
# 10                Cute two story house in San Antonio
# 11                       Historic Redbird Guest House
# 12  Entire home-Peaceful, relaxing, safe neighborhood
# 13                                 Blanco River House
# 14  Spacious 2-story Family Home close to everything!
# 15               Charming Columbus, Tx Guest Quarters
# 16               Charming Columbus, Tx Guest Quarters
# 17                                     The Lake House
# 18                                     The Lake House
# 19                                     The Lake House
# 20                                 Riverfront Retreat
# 21  Beautiful 5BR House Dona Ana Cove, San Antonio...
# 22                 San Antonio Lake House on Lake LBJ
# 23                 San Antonio Lake House on Lake LBJ
#
#                                                   Url   Ranking
# 1   https://www.airbnb.com/rooms/18568735?location...  0.999999
# 2   https://www.airbnb.com/rooms/18568735?location...  0.999999
# 3   https://www.airbnb.com/rooms/18396644?location...  0.999175
# 4   https://www.airbnb.com/rooms/18396644?location...  0.999175
# 5   https://www.airbnb.com/rooms/8557583?location=...  0.997873
# 6   https://www.airbnb.com/rooms/16507221?location...  0.995531
# 7   https://www.airbnb.com/rooms/13299372?location...  0.994811
# 8   https://www.airbnb.com/rooms/19190311?location...  0.992723
# 9   https://www.airbnb.com/rooms/11166341?location...  0.990785
# 10  https://www.airbnb.com/rooms/11166341?location...  0.990785
# 11  https://www.airbnb.com/rooms/18472139?location...  0.988121
# 12  https://www.airbnb.com/rooms/5041349?location=...  0.987222
# 13  https://www.airbnb.com/rooms/7159265?location=...  0.977237
# 14  https://www.airbnb.com/rooms/19586812?location...  0.926919
# 15  https://www.airbnb.com/rooms/18269171?location...  0.873008
# 16  https://www.airbnb.com/rooms/18269171?location...  0.873008
# 17  https://www.airbnb.com/rooms/15820806?location...  0.840380
# 18  https://www.airbnb.com/rooms/15820806?location...  0.840380
# 19  https://www.airbnb.com/rooms/15820806?location...  0.840380
# 20  https://www.airbnb.com/rooms/13528589?location...  0.772892
# 21  https://www.airbnb.com/rooms/12954474?location...  0.693427
# 22  https://www.airbnb.com/rooms/13634952?location...  0.659590
# 23  https://www.airbnb.com/rooms/13634952?location...  0.659590

# %% [markdown]
# ## Bonus Step: Make a nice visualization!

# %% [markdown]
# The user could make a search by location. In that case we want to show all the place avaible on an area with a radius given from the user.
# <br>
# As an example the user can give a location and a distance to consider.

# %%
df['Latitude'] = df['Latitude'].astype('float64')
df['Longitude'] = df['Longitude'].astype('float64')

la,lo = ((29.4722, -98.5247))
pos = []

for lat, long in zip(df.Latitude, df.Longitude): 
    tmp = [] 
    tmp.append(lat)
    tmp.append(long)
    pos.append(tmp) 
    
dist = 50   #in kms

# %% [markdown]
# The final step is to create a map where is shown the location given by the user and all the places found from the search.
# <br>
# To better visualize the area it's shown a circle of the considered area.

# %%
m = fl.Map(location=[la, lo], zoom_start=12)

for n,loc in enumerate(pos):
    dis = distance.distance([la, lo], loc).km 
    fl.Marker([la, lo], icon=fl.Icon(color='red')).add_to(m)
    if dis <= dist:
        fl.Marker(loc, tooltip=df['Average_rate_per_night'][n+1]).add_to(m)


fl.Circle(
    location=[la, lo],
    radius=dist*1000, 
    fill=True,
    fill_color='#3186cc'
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('my_map.html')
